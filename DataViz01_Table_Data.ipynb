# %% [markdown]
# <a href="https://colab.research.google.com/github/sujiraa/BasicProg_DataViz65/blob/main/DataViz01_Table_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
set(df['Name']) #เลือกค่าที่ไม่ซ้ำ
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %%
df['Name'].unique() #เลือกค่าที่ไม่ซ้ำ
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ##Parallel Coordinates

# %%
pd.plotting.parallel_coordinates(df, 'Name') #df=ชื่อตาราง Name=จัดกลุ่มตามname

# %%
pd.plotting.parallel_coordinates(df, 'Name',cols = ['SepalLength','PetalLength'])

# %% [markdown]
# ##change color

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=['r','y','k'])

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=['c', 'm', 'w'])

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=[[0.5,0.1,0.1],[1,1,0],[0.2,0.4,0.7]]) # r gเขียว bฟ้า

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=['#FF00E0', '#00FFE2', '#ECFF00'])

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=['#A73B24', '#FF9F9D', '#88B46c'])

# %% [markdown]
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
pd.plotting.parallel_coordinates(df, 'Name', colormap='magma')

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib

# %%
matplotlib.rcParams['figure.figsize']=[25,25] #กำหนดขนาดของ figure
plt.imshow(df.iloc[:,:-1],interpolation='nearest') #สีสว่าง ค่ามาก สีเข้ม ค่าน้อย

# %%
plt.imshow(df.iloc[:,:-1],interpolation='nearest',cmap = 'hot') #cmap กำหนดสี

# %% [markdown]
# #Subplot

# %%
matplotlib.rcParams['figure.figsize']=[10,10] #ขนาด

# %%
plt.subplot(1,3,1)  # subplot(มีกี่แถว, มีกี่หลัก, เป็นตัวที่เท่าไหร่)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest') #50 = ตัวที่50

plt.subplot(1,3,2)
plt.imshow(df.iloc[50:100,:-1],interpolation='nearest') # 50-100

plt.subplot(1,3,3)
plt.imshow(df.iloc[100:150,:-1],interpolation='nearest')# 100-150

# %%
plt.subplot(1,4,1)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest')

plt.subplot(1,4,2)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',alpha = 0.2)

plt.subplot(1,4,3)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',alpha = 0.5)

plt.subplot(1,4,4)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',alpha = 0.8) #alpha คือความโปร่งใส 1-0

# %%
plt.subplot(1,2,1)
pd.plotting.parallel_coordinates(df, 'Name', color=[[0.5,0.5,0.5,0.5],[0,0,0.8,0.5],[0.2,0.4,0.7,0.5]]) # ตัวเลขที่สี่คือ alpha

plt.subplot(1,2,2)
pd.plotting.parallel_coordinates(df, 'Name', color=[[0.5,0.5,0.5],[0,0,0.8],[0.2,0.4,0.7]])

# %% [markdown]
# #HW3
# วาดกราฟ parallel coordinate เปรียบเทียบ [ราคา และ พื้นที่ใช้สอย] ของบ้านเเละคอนโดในจังหวัดเชียงใหม่

# %% [markdown]
# ##Scatter plot

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter([1,-1],[2,-1])

# %%
plt.scatter(df['PetalLength'],df['SepalLength'])

# %%
plt.scatter(df['PetalLength'],df['SepalLength'],c='r')

# %% [markdown]
# #ระบุสีให้จุด

# %%
set(df['Name'])
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %% [markdown]
# แทนค่าชื่อดอกไม้ด้วยตัวอักษรแทนสี (r g b c m y k w)

# %%
df2 = df.replace({'Iris-setosa':'r', 'Iris-versicolor':'g', 'Iris-virginica':'b'})

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name'])#ใส่ชุดสีได้เเต่จำนวนเเกนx y ต้องเท่ากัน

# %%
plt.scatter(df2['PetalLength'],df2['SepalWidth'],c=df2['Name'])

# %%
plt.scatter(df2['SepalLength'],df2['SepalWidth'],c=df2['Name'])

# %% [markdown]
# ##เพิ่มรายละเอียดกราฟ

# %% [markdown]
# ชื่อเเกน

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name'])
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# ชื่อ marker

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa')#กลุ่มที่1  x 50 ตัวเเรก  y 50  ตัวเเรก สี50 ตัวเเรก
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga')
plt.legend()#ใส่ input ได้
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# # ชื่อกราฟ

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa')#กลุ่มที่1  x 50 ตัวเเรก  y 50  ตัวเเรก สี50 ตัวเเรก
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga')
plt.legend()#ใส่ input ได้
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('Comparing petal&sepal length of different iris flowers'); #ชื่อกราฟ

# %% [markdown]
# ใช้ ขนาดของ marker ในการแสดงค่าใน column

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=df2['PetalWidth'][:50])#s=df2['PetalWidth'][:50] ขนาดของวงกลม
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga',s=df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ขยายขนาด

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50])# 40* คูณ40
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ปรับความโปรงใสของ marker เพื่อให้มองเห็นจุดที่ถูกบัง (Bubble Chart)

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50]) #alpha=0.5
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers \n(sizes of the circle determine petal widths of the flowers ');

# %% [markdown]
# เปลี่ยน หน้าตาของ Marker เพื่อความสวยงาม

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50],marker='X') #alpha=0.5
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100],marker='X')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:],marker='X')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers \n(sizes of the circle determine petal widths of the flowers ');

# %% [markdown]
# แสดงแบบ 3 มิติ

# %%
ax = plt.axes(projection = "3d")
ax.scatter(df2['PetalLength'],df2['SepalLength'],df2['SepalWidth'],c=df2['Name'],s=80*df2['PetalWidth'])#เพิ่มเเกนz
