# %% [markdown]
# <a href="https://colab.research.google.com/github/sujiraa/BasicProg_DataViz65/blob/main/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
day0 = pd.read_excel('/content/drive/MyDrive/Big Data/คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx',sheet_name=0,skiprows=1)
day0.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0      NaN               NaN
# 1  SC 6501  08:00 – 10.00 น.
# 2      NaN               NaN
# 3      NaN               NaN
# 4      NaN               NaN
#
#                                           ชื่อเรื่อง              นักศึกษา  \
# 0                                                NaN                   NaN
# 1  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...  leaky-rust-chameleon
# 2                                                NaN    greasy-ruby-bombay
# 3                                                NaN  leaky-rust-chameleon
# 4                                                NaN    greasy-ruby-bombay
#
#      อาจารย์  กรรมการสอบ  ความชัดเจนของโจทย์การวิจัย  \
# 0  ที่ปรึกษา         NaN                          10
# 1  ดร.ธิปไตย  ผศ.วุฒิชัย                           8
# 2        NaN         NaN                           8
# 3        NaN    อ.ยุภาพร                           9
# 4        NaN         NaN                           9
#
# ...

# %%
day1 = pd.read_excel('/content/drive/MyDrive/Big Data/คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx',sheet_name=1,skiprows=1)
day1.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0      NaN               NaN
# 1  SC 6501  08:00 – 10.00 น.
# 2      NaN               NaN
# 3      NaN               NaN
# 4      NaN               NaN
#
#                                           ชื่อเรื่อง  \
# 0                                                NaN
# 1  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                      นักศึกษา    อาจารย์ กรรมการสอบ  \
# 0                         NaN  ที่ปรึกษา        NaN
# 1            tasty-myrtle-ant  รศ.วิชุดา  ดร.ธนพงศ์
# 2  skanky-burgundy-kingfisher        NaN        NaN
# 3            tasty-myrtle-ant        NaN   ดร.พลากร
# 4  skanky-burgundy-kingfisher        NaN        NaN
#
#    ความชัดเจนของโจทย์การวิจัย  ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง  \
# ...

# %%
day2 = pd.read_excel('/content/drive/MyDrive/Big Data/คะแนนสอบปากเปล่าของกรรมการสอบ_renamed.xlsx',sheet_name=2,skiprows=1)
day2.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0      NaN               NaN
# 1  SC 6501  08:00 – 10.00 น.
# 2      NaN               NaN
# 3      NaN  10:00 – 12.00 น.
# 4      NaN               NaN
#
#                                           ชื่อเรื่อง                นักศึกษา  \
# 0                                                NaN                     NaN
# 1  29.พฤติกรรมการใช้แอพพลิเคชั่นในการเรียนออนไลน์...      frumpy-gamboge-emu
# 2                                                NaN                     NaN
# 3  30.ความคิดเห็นของนักศึกษาเกี่ยวกับคุณภาพสารสนเ...  ugly-harlequin-octopus
# 4                                                NaN   craggy-cream-paradise
#
#      อาจารย์  กรรมการสอบ  ความชัดเจนของโจทย์การวิจัย  \
# 0  ที่ปรึกษา         NaN                        10.0
# 1  รศ.วิชุดา   ดร.ธิปไตย                         8.0
# 2        NaN  รศ.สุพรรณี                         6.0
# 3  รศ.วิชุดา   ดร.ธิปไตย                         9.0
# ...

# %%
data1_0 = day0.fillna(method='ffill')
data1_0.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0      NaN               NaN
# 1  SC 6501  08:00 – 10.00 น.
# 2  SC 6501  08:00 – 10.00 น.
# 3  SC 6501  08:00 – 10.00 น.
# 4  SC 6501  08:00 – 10.00 น.
#
#                                           ชื่อเรื่อง              นักศึกษา  \
# 0                                                NaN                   NaN
# 1  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...  leaky-rust-chameleon
# 2  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...    greasy-ruby-bombay
# 3  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...  leaky-rust-chameleon
# 4  1.การศึกษาแนวทางการประกันภัยพืชผลสำหรับมันสำปะ...    greasy-ruby-bombay
#
#      อาจารย์  กรรมการสอบ  ความชัดเจนของโจทย์การวิจัย  \
# 0  ที่ปรึกษา         NaN                          10
# 1  ดร.ธิปไตย  ผศ.วุฒิชัย                           8
# 2  ดร.ธิปไตย  ผศ.วุฒิชัย                           8
# 3  ดร.ธิปไตย    อ.ยุภาพร                           9
# 4  ดร.ธิปไตย    อ.ยุภาพร                           9
#
# ...

# %%
data1_0 = data1_0.dropna(subset=['ห้องสอบ','เวลา', 'ชื่อเรื่อง'])

# %%
data1_1 = day1.fillna(method='ffill')
data1_1.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0      NaN               NaN
# 1  SC 6501  08:00 – 10.00 น.
# 2  SC 6501  08:00 – 10.00 น.
# 3  SC 6501  08:00 – 10.00 น.
# 4  SC 6501  08:00 – 10.00 น.
#
#                                           ชื่อเรื่อง  \
# 0                                                NaN
# 1  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 2  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 3  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
# 4  15.การพัฒนาระบบสารสนเทศเพื่อสืบค้นโครงงานผ่านเ...
#
#                      นักศึกษา    อาจารย์ กรรมการสอบ  \
# 0                         NaN  ที่ปรึกษา        NaN
# 1            tasty-myrtle-ant  รศ.วิชุดา  ดร.ธนพงศ์
# 2  skanky-burgundy-kingfisher  รศ.วิชุดา  ดร.ธนพงศ์
# 3            tasty-myrtle-ant  รศ.วิชุดา   ดร.พลากร
# 4  skanky-burgundy-kingfisher  รศ.วิชุดา   ดร.พลากร
#
#    ความชัดเจนของโจทย์การวิจัย  ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง  \
# ...

# %%
data1_1 = data1_1.dropna(subset=['ห้องสอบ','เวลา', 'ชื่อเรื่อง'])

# %%
data1_2 = day2.fillna(method='ffill')
data1_2.head()
# Out:
#    ห้องสอบ              เวลา  \
# 0      NaN               NaN
# 1  SC 6501  08:00 – 10.00 น.
# 2  SC 6501  08:00 – 10.00 น.
# 3  SC 6501  10:00 – 12.00 น.
# 4  SC 6501  10:00 – 12.00 น.
#
#                                           ชื่อเรื่อง                นักศึกษา  \
# 0                                                NaN                     NaN
# 1  29.พฤติกรรมการใช้แอพพลิเคชั่นในการเรียนออนไลน์...      frumpy-gamboge-emu
# 2  29.พฤติกรรมการใช้แอพพลิเคชั่นในการเรียนออนไลน์...      frumpy-gamboge-emu
# 3  30.ความคิดเห็นของนักศึกษาเกี่ยวกับคุณภาพสารสนเ...  ugly-harlequin-octopus
# 4  30.ความคิดเห็นของนักศึกษาเกี่ยวกับคุณภาพสารสนเ...   craggy-cream-paradise
#
#      อาจารย์  กรรมการสอบ  ความชัดเจนของโจทย์การวิจัย  \
# 0  ที่ปรึกษา         NaN                        10.0
# 1  รศ.วิชุดา   ดร.ธิปไตย                         8.0
# 2  รศ.วิชุดา  รศ.สุพรรณี                         6.0
# 3  รศ.วิชุดา   ดร.ธิปไตย                         9.0
# ...

# %%
data1_2 = data1_2.dropna(subset=['ห้องสอบ','เวลา', 'ชื่อเรื่อง'])

# %%
data1_2.isnull().any()
# Out:
# ห้องสอบ                                          False
# เวลา                                             False
# ชื่อเรื่อง                                       False
# นักศึกษา                                         False
# อาจารย์                                          False
# กรรมการสอบ                                       False
# ความชัดเจนของโจทย์การวิจัย                       False
# ความครอบคลุมของทฤษฎีและ วรรณกรรมที่เกี่ยวข้อง    False
# ความถูกต้องของระเบียบวิธีวิจัย                   False
# สื่อการนำเสนอ                                    False
# ความสามารถในการนำเสนอและตอบคำถาม                 False
# ความถูกต้องของเนื้อหาในเล่มรายงาน                False
# รวม                                              False
# dtype: bool

# %%
all_aj_list = set(list(data1_1['กรรมการสอบ'].dropna()))
all_aj_list
# Out:
# {'ดร.ธนพงศ์',
#  'ดร.ธิปไตย',
#  'ดร.พลากร',
#  'ดร.อุทุมพร',
#  'ผศ.วุฒิชัย',
#  'ผศ.สุกัญญา',
#  'รศ.ธิดาเดียว',
#  'รศ.วิชุดา',
#  'รศ.สุพรรณี',
#  'อ.ธรรณญพร',
#  'อ.ยุภาพร'}

# %% [markdown]
# # Advisor

# %%
advisor1 = pd.read_excel('/content/drive/MyDrive/Big Data/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ดร.ธิปไตย',skiprows=1)
advisor1.head()
# Out:
#              Unnamed: 0  \
# 0                   NaN
# 1  leaky-rust-chameleon
# 2    greasy-ruby-bombay
# 3   wiggy-silver-drever
# 4       stinky-red-chow
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor1.isnull().any()
# Out:
# Unnamed: 0                                                                                    True
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor1.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor1.head(3)
# Out:
#               ชื่อ-สกุล  \
# 0                   NaN
# 1  leaky-rust-chameleon
# 2    greasy-ruby-bombay
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                  9
# 2                                                  7
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# 1                                      5
# ...

# %%
advisor1 = advisor1.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor1.isnull().any()
# Out:
# ชื่อ-สกุล                                                                                    False
# 1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ    False
# 2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย                   False
# 3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา                                 False
# 4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)                                                        False
# 5. ความใส่ใจในการจัดพิมพ์เอกสาร เช่น ความถูกต้อง การแก้ไขตามที่ให้ข้อเสนอแนะไปแล้ว           False
# 6. สามารถควบคุมโครงงานให้ดำเนินการเป็นไปตามแผน                                               False
# 7. ความคิดสร้างสรรค์ ความสามารถวางแผนในการทำงาน การแก้ปัญหาในระหว่างการทำงาน                 False
# ความสมบูรณ์ของเล่ม (8.1 การค้นคว้าข้อมูล หรือแสวงหาความรู้เพิ่มเติม)                         False
# ...

# %%
advisor2 = pd.read_excel('/content/drive/MyDrive/Big Data/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='รศ.ธิดาเดียว',skiprows=1)
advisor2.head()
# Out:
#                   Unnamed: 0  \
# 0                        NaN
# 1          paltry-plum-saola
# 2        cloudy-wheat-bobcat
# 3  gloppy-persimmon-flamingo
# 4       sleepy-gamboge-zebra
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor2.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor2.head(3)
# Out:
#              ชื่อ-สกุล  \
# 0                  NaN
# 1    paltry-plum-saola
# 2  cloudy-wheat-bobcat
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                  9
# 2                                                  9
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# 1                                      5
# ...

# %%
advisor2 = advisor2.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor3 = pd.read_excel('/content/drive/MyDrive/Big Data/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ผศ.สุกัญญา',skiprows=1)
advisor3.head()
# Out:
#                 Unnamed: 0  \
# 0                      NaN
# 1         whiny-pear-otter
# 2    craggy-cream-reindeer
# 3       cloudy-myrtle-kudu
# 4  lovely-asparagus-urchin
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor3.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor3.head(3)
# Out:
#                ชื่อ-สกุล  \
# 0                    NaN
# 1       whiny-pear-otter
# 2  craggy-cream-reindeer
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                  8
# 2                                                  8
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# 1                                      5
# ...

# %%
advisor3 = advisor3.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor4 = pd.read_excel('/content/drive/MyDrive/Big Data/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ดร.ธนพงศ์',skiprows=1)
advisor4.head()
# Out:
#                  Unnamed: 0  \
# 0                       NaN
# 1       jumpy-apricot-frise
# 2  boozy-thistle-wildebeest
# 3      hasty-magnolia-devil
# 4   chummy-goldenrod-walrus
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor4.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor4.head(3)
# Out:
#                   ชื่อ-สกุล  \
# 0                       NaN
# 1       jumpy-apricot-frise
# 2  boozy-thistle-wildebeest
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                 10
# 2                                                  9
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# ...

# %%
advisor4 = advisor4.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor5 = pd.read_excel('/content/drive/MyDrive/Big Data/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ผศ.วุฒิชัย',skiprows=1)
advisor5.head()
# Out:
#               Unnamed: 0  \
# 0                    NaN
# 1     lumpy-carmine-slug
# 2  snappy-azure-balinese
# 3     pasty-bronze-booby
# 4  pokey-asparagus-frise
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  4
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor5.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor5.head(3)
# Out:
#                ชื่อ-สกุล  \
# 0                    NaN
# 1     lumpy-carmine-slug
# 2  snappy-azure-balinese
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                 10
# 2                                                  9
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                    5.0
# 1                                    NaN
# ...

# %%
advisor5 = advisor5.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor6 = pd.read_excel('/content/drive/MyDrive/Big Data/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='รศ.สุพรรณี',skiprows=1)
advisor6.head()
# Out:
#                 Unnamed: 0  \
# 0                      NaN
# 1  chewy-persimmon-catfish
# 2  skanky-amaranth-ostrich
# 3   greasy-eggplant-oyster
# 4         randy-mauve-ibis
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                5.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                5.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor6.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor6.head(3)
# Out:
#                  ชื่อ-สกุล  \
# 0                      NaN
# 1  chewy-persimmon-catfish
# 2  skanky-amaranth-ostrich
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                5.0
# 1                                                NaN
# 2                                                NaN
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                5.0
# 1                                                NaN
# 2                                                NaN
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                               10.0
# 1                                                NaN
# 2                                                NaN
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                    5.0
# ...

# %%
advisor6 = advisor6.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor7= pd.read_excel('/content/drive/MyDrive/Big Data/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='อ.ยุภาพร',skiprows=1)
advisor7.head()
# Out:
#                  Unnamed: 0  \
# 0                       NaN
# 1     nerdy-plum-abyssinian
# 2  gloppy-xanthic-retriever
# 3     cloudy-myrtle-whippet
# 4        cloudy-grey-walrus
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor7.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor7.head(3)
# Out:
#                   ชื่อ-สกุล  \
# 0                       NaN
# 1     nerdy-plum-abyssinian
# 2  gloppy-xanthic-retriever
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                 10
# 2                                                 10
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# ...

# %%
advisor7 = advisor7.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor8 = pd.read_excel('/content/drive/MyDrive/Big Data/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ดร.พลากร',skiprows=1)
advisor8.head()
# Out:
#               Unnamed: 0  \
# 0                    NaN
# 1  craggy-mustard-sponge
# 2    fuzzy-silver-discus
# 3        lousy-corn-mule
# 4   muggy-charcoal-akita
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor8.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor8.head(3)
# Out:
#                ชื่อ-สกุล  \
# 0                    NaN
# 1  craggy-mustard-sponge
# 2    fuzzy-silver-discus
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  4
# 2                                                  4
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                  8
# 2                                                  8
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# 1                                      5
# ...

# %%
advisor8 = advisor8.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor9 = pd.read_excel('/content/drive/MyDrive/Big Data/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='รศ.วิชุดา',skiprows=1)
advisor9.head()
# Out:
#                    Unnamed: 0  \
# 0                         NaN
# 1            tasty-myrtle-ant
# 2  skanky-burgundy-kingfisher
# 3          sleazy-mauve-akita
# 4       crappy-burgundy-quoll
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
# 3                                                5.0
# 4                                                5.0
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
# 3                                                5.0
# 4                                                5.0
#
# ...

# %%
advisor9.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor9.head(3)
# Out:
#                     ชื่อ-สกุล  \
# 0                         NaN
# 1            tasty-myrtle-ant
# 2  skanky-burgundy-kingfisher
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                               10.0
# 1                                                8.0
# 2                                                8.0
#
#   4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                     5
# ...

# %%
advisor9 = advisor9.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor10 = pd.read_excel('/content/drive/MyDrive/Big Data/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ดร.วรรณพร',skiprows=1)
advisor10.head()
# Out:
#                Unnamed: 0  \
# 0                     NaN
# 1  skinny-bronze-dormouse
# 2    freaky-lemon-peccary
# 3       flabby-green-fish
# 4  skinny-heliotrope-kudu
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor10.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor10.head(3)
# Out:
#                 ชื่อ-สกุล  \
# 0                     NaN
# 1  skinny-bronze-dormouse
# 2    freaky-lemon-peccary
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                  8
# 2                                                  7
#
#   4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                     5
# 1                                     5
# ...

# %%
advisor10 = advisor10.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor11= pd.read_excel('/content/drive/MyDrive/Big Data/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='อ.ธรรณญพร',skiprows=1)
advisor11.head()
# Out:
#                     Unnamed: 0  \
# 0                          NaN
# 1            chewy-lilac-shark
# 2   greasy-olivine-neanderthal
# 3  hasty-dandelion-grasshopper
# 4           ugly-myrtle-walrus
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
# ...

# %%
advisor11.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor11.head(3)
# Out:
#                     ชื่อ-สกุล  \
# 0                         NaN
# 1           chewy-lilac-shark
# 2  greasy-olivine-neanderthal
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                  8
# 2                                                  8
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# ...

# %%
advisor11 = advisor11.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisor12= pd.read_excel('/content/drive/MyDrive/Big Data/คะแนนอาจารย์ที่ปรึกษา_renamed.xlsx',sheet_name='ดร.อุทุมพร',skiprows=1)
advisor12.head()
# Out:
#                 Unnamed: 0  \
# 0                      NaN
# 1      chummy-azure-walrus
# 2        breezy-pear-macaw
# 3  cozy-tangerine-ladybird
# 4     scaly-pumpkin-monkey
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  4
# 4                                                  4
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# ...

# %%
advisor12.rename(columns={'Unnamed: 0': 'ชื่อ-สกุล', 'Unnamed: 12': 'ชื่อเรื่อง'}, inplace=True)
advisor12.head(3)
# Out:
#              ชื่อ-สกุล  \
# 0                  NaN
# 1  chummy-azure-walrus
# 2    breezy-pear-macaw
#
#    1. ความกระตือรือร้น ความมุ่งมั่น ความขยันหมั่นเพียร ความตั้งใจในการทำงาน และความรับผิดชอบ  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    2. ความสม่ำเสมอในการเข้าพบอาจารย์ที่ปรึกษา และมาพบตรงตามวัน/เวลาที่นัดหมาย  \
# 0                                                  5
# 1                                                  5
# 2                                                  5
#
#    3. ความสามารถในการอธิบายหรือการนำเสนอต่อหน้าอาจารย์ที่ปรึกษา  \
# 0                                                 10
# 1                                                  9
# 2                                                 10
#
#    4. การทำงานเป็นทีม (กรณีที่ทำเป็นคู่)  \
# 0                                      5
# 1                                      5
# ...

# %%
advisor12 = advisor12.dropna(subset=['ชื่อ-สกุล', 'ชื่อเรื่อง'])

# %%
advisorall0 =pd.merge(advisor1,advisor2)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py:1218: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   UserWarning,

# %%
advisorall1 =pd.merge(advisorall0,advisor3)

# %%
advisorall2 =pd.merge(advisorall1,advisor4)
